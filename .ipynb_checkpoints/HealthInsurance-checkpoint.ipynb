# %%
import numpy as np
import pandas as pd 

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read data from csv
data = pd.read_csv("./data1/train.csv")

# %%
data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
unseen=data.sample(frac=.10,random_state=42)
train=data.drop(unseen.index)
unseen.to_csv('./data1/unseen.csv',index=False)
train.to_csv('./data1/train1.csv',index=False)
unseen.shape,train.shape
# Out:
# ((38111, 12), (342998, 12))

# %%
from pycaret.classification import ClassificationExperiment
test=ClassificationExperiment()

# %%
test.setup(train,target='Response',session_id=66)
# Out:
# <style type="text/css">
# #T_29f5c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_29f5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29f5c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_29f5c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29f5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29f5c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_29f5c_row0_col1" class="data row0 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29f5c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_29f5c_row1_col1" class="data row1 col1" >Response</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29f5c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_29f5c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29f5c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_29f5c_row3_col1" class="data row3 col1" >(342998, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29f5c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_29f5c_row4_col1" class="data row4 col1" >(342998, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29f5c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_29f5c_row5_col1" class="data row5 col1" >(240098, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29f5c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_29f5c_row6_col1" class="data row6 col1" >(102900, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29f5c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_29f5c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29f5c_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_29f5c_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29f5c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_29f5c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_29f5c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_29f5c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_29f5c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_29f5c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_29f5c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_29f5c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_29f5c_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_29f5c_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_29f5c_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_29f5c_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_29f5c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_29f5c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_29f5c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_29f5c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_29f5c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_29f5c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_29f5c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_29f5c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_29f5c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_29f5c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_29f5c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_29f5c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_29f5c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_29f5c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_29f5c_row21_col1" class="data row21 col1" >a92f</td>
#     </tr>
#   </tbody>
# </table>

# %%
test.compare_models()
# Out:
# <style type="text/css">
# #T_a02cc th {
#   text-align: left;
# }
# #T_a02cc_row0_col0, #T_a02cc_row0_col3, #T_a02cc_row0_col4, #T_a02cc_row0_col5, #T_a02cc_row0_col6, #T_a02cc_row0_col7, #T_a02cc_row1_col0, #T_a02cc_row1_col3, #T_a02cc_row1_col4, #T_a02cc_row1_col5, #T_a02cc_row1_col6, #T_a02cc_row1_col7, #T_a02cc_row2_col0, #T_a02cc_row2_col3, #T_a02cc_row2_col4, #T_a02cc_row2_col5, #T_a02cc_row2_col6, #T_a02cc_row2_col7, #T_a02cc_row3_col0, #T_a02cc_row3_col1, #T_a02cc_row3_col3, #T_a02cc_row3_col4, #T_a02cc_row3_col5, #T_a02cc_row3_col6, #T_a02cc_row3_col7, #T_a02cc_row4_col0, #T_a02cc_row4_col1, #T_a02cc_row4_col3, #T_a02cc_row4_col4, #T_a02cc_row4_col5, #T_a02cc_row4_col6, #T_a02cc_row4_col7, #T_a02cc_row5_col0, #T_a02cc_row5_col1, #T_a02cc_row5_col3, #T_a02cc_row5_col4, #T_a02cc_row5_col5, #T_a02cc_row5_col6, #T_a02cc_row5_col7, #T_a02cc_row6_col0, #T_a02cc_row6_col1, #T_a02cc_row6_col3, #T_a02cc_row6_col4, #T_a02cc_row6_col5, #T_a02cc_row6_col6, #T_a02cc_row6_col7, #T_a02cc_row7_col0, #T_a02cc_row7_col1, #T_a02cc_row7_col3, #T_a02cc_row7_col4, #T_a02cc_row7_col5, #T_a02cc_row7_col6, #T_a02cc_row7_col7, #T_a02cc_row8_col0, #T_a02cc_row8_col1, #T_a02cc_row8_col3, #T_a02cc_row8_col5, #T_a02cc_row8_col6, #T_a02cc_row8_col7, #T_a02cc_row9_col0, #T_a02cc_row9_col1, #T_a02cc_row9_col3, #T_a02cc_row9_col4, #T_a02cc_row9_col5, #T_a02cc_row9_col6, #T_a02cc_row9_col7, #T_a02cc_row10_col0, #T_a02cc_row10_col1, #T_a02cc_row10_col3, #T_a02cc_row10_col4, #T_a02cc_row10_col5, #T_a02cc_row10_col6, #T_a02cc_row10_col7, #T_a02cc_row11_col0, #T_a02cc_row11_col1, #T_a02cc_row11_col3, #T_a02cc_row11_col4, #T_a02cc_row11_col5, #T_a02cc_row11_col6, #T_a02cc_row11_col7, #T_a02cc_row12_col0, #T_a02cc_row12_col1, #T_a02cc_row12_col3, #T_a02cc_row12_col4, #T_a02cc_row12_col5, #T_a02cc_row12_col6, #T_a02cc_row12_col7, #T_a02cc_row13_col0, #T_a02cc_row13_col1, #T_a02cc_row13_col3, #T_a02cc_row13_col4, #T_a02cc_row13_col5, #T_a02cc_row13_col6, #T_a02cc_row13_col7, #T_a02cc_row14_col0, #T_a02cc_row14_col1, #T_a02cc_row14_col4 {
#   text-align: left;
# }
# #T_a02cc_row0_col1, #T_a02cc_row0_col2, #T_a02cc_row1_col1, #T_a02cc_row1_col2, #T_a02cc_row2_col1, #T_a02cc_row2_col2, #T_a02cc_row3_col2, #T_a02cc_row4_col2, #T_a02cc_row5_col2, #T_a02cc_row6_col2, #T_a02cc_row7_col2, #T_a02cc_row8_col2, #T_a02cc_row8_col4, #T_a02cc_row9_col2, #T_a02cc_row10_col2, #T_a02cc_row11_col2, #T_a02cc_row12_col2, #T_a02cc_row13_col2, #T_a02cc_row14_col2, #T_a02cc_row14_col3, #T_a02cc_row14_col5, #T_a02cc_row14_col6, #T_a02cc_row14_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a02cc_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_a02cc_row1_col8, #T_a02cc_row2_col8, #T_a02cc_row3_col8, #T_a02cc_row4_col8, #T_a02cc_row5_col8, #T_a02cc_row6_col8, #T_a02cc_row7_col8, #T_a02cc_row8_col8, #T_a02cc_row9_col8, #T_a02cc_row10_col8, #T_a02cc_row11_col8, #T_a02cc_row12_col8, #T_a02cc_row13_col8, #T_a02cc_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a02cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a02cc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a02cc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a02cc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a02cc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a02cc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a02cc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a02cc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a02cc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a02cc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a02cc_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_a02cc_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_a02cc_row0_col1" class="data row0 col1" >0.8778</td>
#       <td id="T_a02cc_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_a02cc_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_a02cc_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_a02cc_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_a02cc_row0_col6" class="data row0 col6" >-0.0000</td>
#       <td id="T_a02cc_row0_col7" class="data row0 col7" >-0.0002</td>
#       <td id="T_a02cc_row0_col8" class="data row0 col8" >0.6830</td>
#     </tr>
#     <tr>
#       <th id="T_a02cc_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_a02cc_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_a02cc_row1_col1" class="data row1 col1" >0.8778</td>
#       <td id="T_a02cc_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_a02cc_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_a02cc_row1_col4" class="data row1 col4" >0.1000</td>
#       <td id="T_a02cc_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_a02cc_row1_col6" class="data row1 col6" >0.0001</td>
#       <td id="T_a02cc_row1_col7" class="data row1 col7" >0.0017</td>
#       <td id="T_a02cc_row1_col8" class="data row1 col8" >6.5740</td>
#     </tr>
#     <tr>
#       <th id="T_a02cc_level0_row2" class="row_heading level0 row2" >dummy</th>
#       <td id="T_a02cc_row2_col0" class="data row2 col0" >Dummy Classifier</td>
#       <td id="T_a02cc_row2_col1" class="data row2 col1" >0.8778</td>
#       <td id="T_a02cc_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_a02cc_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_a02cc_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_a02cc_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_a02cc_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_a02cc_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_a02cc_row2_col8" class="data row2 col8" >0.7100</td>
#     </tr>
#     <tr>
#       <th id="T_a02cc_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_a02cc_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a02cc_row3_col1" class="data row3 col1" >0.8777</td>
#       <td id="T_a02cc_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_a02cc_row3_col3" class="data row3 col3" >0.0003</td>
#       <td id="T_a02cc_row3_col4" class="data row3 col4" >0.2900</td>
#       <td id="T_a02cc_row3_col5" class="data row3 col5" >0.0005</td>
#       <td id="T_a02cc_row3_col6" class="data row3 col6" >0.0004</td>
#       <td id="T_a02cc_row3_col7" class="data row3 col7" >0.0063</td>
#       <td id="T_a02cc_row3_col8" class="data row3 col8" >23.4070</td>
#     </tr>
#     <tr>
#       <th id="T_a02cc_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_a02cc_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_a02cc_row4_col1" class="data row4 col1" >0.8774</td>
#       <td id="T_a02cc_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_a02cc_row4_col3" class="data row4 col3" >0.0027</td>
#       <td id="T_a02cc_row4_col4" class="data row4 col4" >0.3284</td>
#       <td id="T_a02cc_row4_col5" class="data row4 col5" >0.0053</td>
#       <td id="T_a02cc_row4_col6" class="data row4 col6" >0.0033</td>
#       <td id="T_a02cc_row4_col7" class="data row4 col7" >0.0197</td>
#       <td id="T_a02cc_row4_col8" class="data row4 col8" >0.7850</td>
#     </tr>
#     <tr>
#       <th id="T_a02cc_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_a02cc_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a02cc_row5_col1" class="data row5 col1" >0.8774</td>
#       <td id="T_a02cc_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_a02cc_row5_col3" class="data row5 col3" >0.0029</td>
#       <td id="T_a02cc_row5_col4" class="data row5 col4" >0.3233</td>
#       <td id="T_a02
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=66, solver='auto',
#                 tol=0.0001)

# %%
ridge=test.create_model('ridge')
# Out:
# <style type="text/css">
# #T_3802d_row10_col0, #T_3802d_row10_col1, #T_3802d_row10_col2, #T_3802d_row10_col3, #T_3802d_row10_col4, #T_3802d_row10_col5, #T_3802d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3802d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3802d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3802d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3802d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3802d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3802d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3802d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3802d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3802d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3802d_row0_col0" class="data row0 col0" >0.8778</td>
#       <td id="T_3802d_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_3802d_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_3802d_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T
row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_0b36b_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_0b36b_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0b36b_row5_col0" class="data row5 col0" >0.8778</td>
#       <td id="T_0b36b_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_0b36b_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_0b36b_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_0b36b_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_0b36b_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_0b36b_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0b36b_row6_col0" class="data row6 col0" >0.8778</td>
#       <td id="T_0b36b_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_0b36b_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_0b36b_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_0b36b_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_0b36b_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_0b36b_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0b36b_row7_col0" class="data row7 col0" >0.8778</td>
#       <td id="T_0b36b_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_0b36b_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_0b36b_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_0b36b_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_0b36b_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_0b36b_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0b36b_row8_col0" class="data row8 col0" >0.8778</td>
#       <td id="T_0b36b_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_0b36b_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_0b36b_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_0b36b_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_0b36b_row8_col5" class="data row8 col5" >-0.0001</td>
#       <td id="T_0b36b_row8_col6" class="data row8 col6" >-0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0b36b_row9_col0" class="data row9 col0" >0.8778</td>
#       <td id="T_0b36b_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_0b36b_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_0b36b_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_0b36b_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_0b36b_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_0b36b_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0b36b_row10_col0" class="data row10 col0" >0.8778</td>
#       <td id="T_0b36b_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_0b36b_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_0b36b_row10_col3" class="data row10 col3" >0.0000</td>
#       <td id="T_0b36b_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_0b36b_row10_col5" class="data row10 col5" >-0.0000</td>
#       <td id="T_0b36b_row10_col6" class="data row10 col6" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_0b36b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0b36b_row11_col0" class="data row11 col0" >0.0000</td>
#       <td id="T_0b36b_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_0b36b_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_0b36b_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_0b36b_row11_
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=66, solver='auto',
#                 tol=0.0001)

# %%
final_ridge=test.finalize_model(tuned_ridge)
final_ridge
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['id', 'Age', 'Driving_License',
#                                              'Region_Code',
#                                              'Previously_Insured',
#                                              'Annual_Premium',
#                                              'Policy_Sales_Channel',
#                                              'Vintage'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='m...
#                  TransformerWrapper(exclude=None, include=['Vehicle_Age'],
#                                     transformer=OneHotEncoder(cols=['Vehicle_Age'],
#                                                               drop_invariant=False,
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               return_df=True,
#                                                               use_cat_names=True,
#                                                               verbose=0))),
#                 ('actual_estimator',
#                  RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True,
#                                  fit_intercept=True, max_iter=None,
#                                  positive=False, random_state=66, solver='auto',
#                                  tol=0.0001))],
#          verbose=False)

# %%
unseen_X=unseen.copy().drop('Response',axis=1)
y=unseen['Response']

prediction=test.predict_model(final_ridge,data=unseen_X)

# %%
from sklearn.metrics import classification_report

# Use classification_report to compare predicted values with actual values
y_pred=prediction['prediction_label']
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     33328
#            1       0.00      0.00      0.00      4783
#
#     accuracy                           0.87     38111
#    macro avg       0.44      0.50      0.47     38111
# weighted avg       0.76      0.87      0.82     38111

# %% [markdown]
# ## Result ##
# * For the '0' Response, the precision is 0.87, indicating that 87% of instances predicted as '0' are indeed '0'. For the '1' Response, is 0.00
# * For the '0' Response, the recall is 1.00, indicating that the model successfully predicts 100% of actual '0' instances. For the '1' Response, the recall is 0.00, meaning that the model correctly predicts 0% of actual '1' instances.
# * It was determined that 1 refers to a non-responding customer. So there is no data generated per se, so it is '0'.
# * Overall, the model performs well in predicting the '0'Response but performs relatively poorly in predicting the '1'.
